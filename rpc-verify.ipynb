# %%
import rasterio as rio

# %%
tif_path = "6c07196f-6be7-4996-b607-17051e315beb_pan.tif"

# %%
with rio.open(tif_path) as src:
    rpc_dict = src.tags(ns="RPC")

# %%
rpc_dict
# Out:
# {'ERR_BIAS': '-1',
#  'ERR_RAND': '-1',
#  'HEIGHT_OFF': '95',
#  'HEIGHT_SCALE': '65',
#  'LAT_OFF': '52.5400320648552',
#  'LAT_SCALE': '0.0967904331056388',
#  'LINE_DEN_COEFF': '1 0.00390509785256048 -0.00301895839445232 1.92736407373377e-06 -1.16724312654982e-05 1.00362218373553e-08 -7.07471230535542e-08 -2.06048958100321e-05 1.56183263796383e-05 -4.62330577601671e-06 3.48964024826779e-09 -1.76433969177741e-08 1.3342366349179e-06 -3.47061366404093e-08 6.22495761270872e-07 1.96775138243389e-07 3.20772980727302e-09 -4.16946843024231e-12 2.98730075382013e-09 -2.13156073222563e-11',
# ...
