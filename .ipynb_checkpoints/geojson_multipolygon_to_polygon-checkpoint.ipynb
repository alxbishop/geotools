# %%
import geojson
import geopandas as gp
from pathlib import Path

# %%
file_path = Path('../projects/00_working/archive_search_sales/notebook/axelspace/aoi/no_cover_area.geojson')

# %%
gdf = gp.read_file(file_path)
gdf
# Out:
#    OBJECTID  Shape_Leng  Shape_Area          SQKM  \
# 0         1  144.813912    6.117086  58764.188477
#
#                                             geometry
# 0  MULTIPOLYGON (((141.47026 24.24207, 141.47147 ...

# %%
i = 0

gdf_explode = gdf.explode()
gdf_explode




# for i in range(len(gdf)):
#     # print(f'{i}:{i+1}')
#     gdf_row = gp.GeoDataFrame.from_features(gdf_explode[i:i+1])

#     print(gdf_row['SQKM'])
    
# filename = str(file_path.stem)+'_'+str(i)+'.geojson'
# print(filename)
# gdf_row.to_file('./projects/00_working/archive_search_sales/notebook/axelspace/aoi/aoi_loop/'+filename, driver='GeoJSON')
# i=+1
# Out:
# /var/folders/my/z8pxnnx57f768bkd7fgtv8700000gq/T/ipykernel_947/2716497781.py:3: FutureWarning: Currently, index_parts defaults to True, but in the future, it will default to False to be consistent with Pandas. Use `index_parts=True` to keep the current behavior and True/False to silence the warning.
#   gdf_explode = gdf.explode()
#         OBJECTID  Shape_Leng  Shape_Area          SQKM  \
# 0 0            1  144.813912    6.117086  58764.188477
#   1            1  144.813912    6.117086  58764.188477
#   2            1  144.813912    6.117086  58764.188477
#   3            1  144.813912    6.117086  58764.188477
#   4            1  144.813912    6.117086  58764.188477
# ...          ...         ...         ...           ...
#   1062         1  144.813912    6.117086  58764.188477
#   1063         1  144.813912    6.117086  58764.188477
#   1064         1  144.813912    6.117086  58764.188477
#   1065         1  144.813912    6.117086  58764.188477
# ...

# %%
# Need to remove fields of type list to export to geojson
# try:
#     del search_results['up42:usageType']
# except KeyError:
#     pass

# Write to geojson
gdf_explode.to_file('./search-report/sr_gdf_explode.geojson', driver='GeoJSON')
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "fiona/ogrext.pyx", line 175, in fiona.ogrext.gdal_create
#   File "fiona/_err.pyx", line 291, in fiona._err.exc_wrap_pointer
# fiona._err.CPLE_OpenFailedError: Failed to create GeoJSON datasource: ./search-report/sr_gdf_explode.geojson: ./search-report/sr_gdf_explode.geojson: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/up42/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3460, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/my/z8pxnnx57f768bkd7fgtv8700000gq/T/ipykernel_947/1049386341.py", line 8, in <module>
#     gdf_explode.to_file('./search-report/sr_gdf_explode.geojson', driver='GeoJSON')
# ...
